# %% [markdown]
# <a href="https://colab.research.google.com/github/Setsuke/AlgorithmComplexityProject/blob/main/TP/SOL-2/Sol_DFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Algoritmo DFS</h1><br>
# <b><i>Seguir el primer camino que encuentres hsta que ya no puedas avanzar más</i></b>
#     <p>Visitar el primer vertice que se encuentre en cada paso hasta que ya no puedas seguir visitando más vertices.</p>

# %% [markdown]
# <h2>Definición de la entrada</h2><br>
# <p>Para usar <code>DFS</code> usaremos una matriz de adjacencia y una lista de visitados <br>
# El input de datos seran la lista de adjacencia el centro poblado de donde partiremos ademas de una lista donde almacenaremos el camino
#
# <p>
#     La funcion <code>valid()</code> se encargará de retornar si la centro poblado que es adyacente al nodo en donde estamos no esta previamente en la lista de  <code>vis</code> .
# </p>

# %%
def DFS(nodito: str, peso: float):
  vis.append(nodito)
  
  i = i + peso

  index = list(orden).index(nodito)
  #Busco su index para recorrer sus vecinos

  q = [] # q es la cola soporte de heapq
  for e, w in adj[index]:
    print(nodito)
    print(str(e)+' '+str(w))
    print('--------')
    pq.heappush(q, (w, e))
  
  while len(q) > 0 :
    n,v = pq.heappop(q)
    if valid(v):
      DFS(v, n)
      break

# %% [markdown]
# <h2>El algoritmo principal</h2>
# <p>
# El <code>DFS</code> va a iterar por todos los nodos partiendo del nodo que se se le dé. A partir de ahí, recorrerá todos los nodos adyacentes, en este caso, las centros poblados adyacentes serán definidas por la lista de adyacencia y para evaluar si se debe o no recorrer el nodo adyacente(la ciudad), se usará la funcion <code>valid()</code> explicada anteriormente.
# </p>
# <p>En los <code>for</code> fuera de <code>dfs()</code> Como <code>dfs()</code> recorrerá todos los nodos que estén a su alcance, podemos asumir que dejará como 'visitados' a todos los nodos a los que pueda acceder, y para que la solucion sea valido, tendría que poder acceder a todos los centros poblados.

# %%
#Data de ejemplo PROVINCIA DE BONGARA
PROVINCIA ={0: {'Destino': 'LA FLORIDA',
  'Distancia': 0.007236614678151118,
  'Origen': 'CHAVIN DE HUANTAR'},
 1: {'Destino': 'SHAYAPA',
  'Distancia': 0.00103697685605998,
  'Origen': 'CHAVIN DE HUANTAR'},
 2: {'Destino': 'POMACHACA',
  'Distancia': 0.198188609950218,
  'Origen': 'CHAVIN DE HUANTAR'},
 3: {'Destino': 'MITUBAMBA',
  'Distancia': 0.25713168787413143,
  'Origen': 'CHAVIN DE HUANTAR'},
 4: {'Destino': 'HUAYTUNA',
  'Distancia': 0.24874887300447845,
  'Origen': 'CHAVIN DE HUANTAR'},
 5: {'Destino': 'MITUBAMBA',
  'Distancia': 0.25713168787413143,
  'Origen': 'CHAVIN DE HUANTAR'},
 6: {'Destino': 'POMACHACA',
  'Distancia': 0.19989512100348686,
  'Origen': 'CHAVIN DE HUANTAR'},
 7: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.2500123277480477,
  'Origen': 'CHAVIN DE HUANTAR'},
 8: {'Destino': 'CARHUAYOC',
  'Distancia': 0.07886109687924713,
  'Origen': 'CHAVIN DE HUANTAR'},
 9: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.0042151262140014455,
  'Origen': 'CHAVIN DE HUANTAR'},
 10: {'Destino': 'GAUCHO',
  'Distancia': 0.005086975722366416,
  'Origen': 'CHAVIN DE HUANTAR'},
 11: {'Destino': 'MARIASH',
  'Distancia': 0.008296129820585687,
  'Origen': 'CHAVIN DE HUANTAR'},
 12: {'Destino': 'AUYO',
  'Distancia': 0.468174040196582,
  'Origen': 'CHAVIN DE HUANTAR'},
 13: {'Destino': 'LUCMA',
  'Distancia': 0.47076697457340555,
  'Origen': 'CHAVIN DE HUANTAR'},
 14: {'Destino': 'PUCHCA',
  'Distancia': 0.470556231140334,
  'Origen': 'CHAVIN DE HUANTAR'},
 15: {'Destino': 'PUCUZ',
  'Distancia': 0.47558701312798235,
  'Origen': 'CHAVIN DE HUANTAR'},
 16: {'Destino': 'PUCUZ',
  'Distancia': 0.461714248270503,
  'Origen': 'CHAVIN DE HUANTAR'},
 17: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.4660475569220338,
  'Origen': 'CHAVIN DE HUANTAR'},
 18: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.4711296062804773,
  'Origen': 'CHAVIN DE HUANTAR'},
 19: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.007236614678151118,
  'Origen': 'LA FLORIDA'},
 20: {'Destino': 'SHAYAPA',
  'Distancia': 0.007455583209918101,
  'Origen': 'LA FLORIDA'},
 21: {'Destino': 'POMACHACA',
  'Distancia': 0.20538029869001664,
  'Origen': 'LA FLORIDA'},
 22: {'Destino': 'MITUBAMBA',
  'Distancia': 0.2643327577978202,
  'Origen': 'LA FLORIDA'},
 23: {'Destino': 'HUAYTUNA',
  'Distancia': 0.25594636364089907,
  'Origen': 'LA FLORIDA'},
 24: {'Destino': 'MITUBAMBA',
  'Distancia': 0.2643327577978202,
  'Origen': 'LA FLORIDA'},
 25: {'Destino': 'POMACHACA',
  'Distancia': 0.20710039865002533,
  'Origen': 'LA FLORIDA'},
 26: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.25720214192342655,
  'Origen': 'LA FLORIDA'},
 27: {'Destino': 'CARHUAYOC',
  'Distancia': 0.08554215031783105,
  'Origen': 'LA FLORIDA'},
 28: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.010144463761086282,
  'Origen': 'LA FLORIDA'},
 29: {'Destino': 'GAUCHO',
  'Distancia': 0.006195002017749864,
  'Origen': 'LA FLORIDA'},
 30: {'Destino': 'MARIASH',
  'Distancia': 0.004718528796140812,
  'Origen': 'LA FLORIDA'},
 31: {'Destino': 'AUYO',
  'Distancia': 0.47526155599837144,
  'Origen': 'LA FLORIDA'},
 32: {'Destino': 'LUCMA',
  'Distancia': 0.47784651649352844,
  'Origen': 'LA FLORIDA'},
 33: {'Destino': 'PUCHCA',
  'Distancia': 0.47766974081366914,
  'Origen': 'LA FLORIDA'},
 34: {'Destino': 'PUCUZ',
  'Distancia': 0.4826611522963063,
  'Origen': 'LA FLORIDA'},
 35: {'Destino': 'PUCUZ',
  'Distancia': 0.4688630801588008,
  'Origen': 'LA FLORIDA'},
 36: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.4731205352053521,
  'Origen': 'LA FLORIDA'},
 37: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.4781965044309714,
  'Origen': 'LA FLORIDA'},
 38: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.00103697685605998,
  'Origen': 'SHAYAPA'},
 39: {'Destino': 'LA FLORIDA',
  'Distancia': 0.007455583209918101,
  'Origen': 'SHAYAPA'},
 40: {'Destino': 'POMACHACA',
  'Distancia': 0.19792787788737617,
  'Origen': 'SHAYAPA'},
 41: {'Destino': 'MITUBAMBA',
  'Distancia': 0.25708955334669004,
  'Origen': 'SHAYAPA'},
 42: {'Destino': 'HUAYTUNA',
  'Distancia': 0.24871198339042475,
  'Origen': 'SHAYAPA'},
 43: {'Destino': 'MITUBAMBA',
  'Distancia': 0.25708955334669004,
  'Origen': 'SHAYAPA'},
 44: {'Destino': 'POMACHACA',
  'Distancia': 0.19965322717651995,
  'Origen': 'SHAYAPA'},
 45: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.24998567982386113,
  'Origen': 'SHAYAPA'},
 46: {'Destino': 'CARHUAYOC',
  'Distancia': 0.0791424793141983,
  'Origen': 'SHAYAPA'},
 47: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.005046805920577871,
  'Origen': 'SHAYAPA'},
 48: {'Destino': 'GAUCHO',
  'Distancia': 0.006045383445236792,
  'Origen': 'SHAYAPA'},
 49: {'Destino': 'MARIASH',
  'Distancia': 0.009031882915539536,
  'Origen': 'SHAYAPA'},
 50: {'Destino': 'AUYO',
  'Distancia': 0.46823912861378036,
  'Origen': 'SHAYAPA'},
 51: {'Destino': 'LUCMA',
  'Distancia': 0.47083766238906494,
  'Origen': 'SHAYAPA'},
 52: {'Destino': 'PUCHCA',
  'Distancia': 0.47060187124574526,
  'Origen': 'SHAYAPA'},
 53: {'Destino': 'PUCUZ',
  'Distancia': 0.47566139576908845,
  'Origen': 'SHAYAPA'},
 54: {'Destino': 'PUCUZ',
  'Distancia': 0.46172985979357806,
  'Origen': 'SHAYAPA'},
 55: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.46612278816637787,
  'Origen': 'SHAYAPA'},
 56: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.47120890887694306,
  'Origen': 'SHAYAPA'},
 57: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.198188609950218,
  'Origen': 'POMACHACA'},
 58: {'Destino': 'LA FLORIDA',
  'Distancia': 0.20538029869001664,
  'Origen': 'POMACHACA'},
 59: {'Destino': 'SHAYAPA',
  'Distancia': 0.19792787788737617,
  'Origen': 'POMACHACA'},
 60: {'Destino': 'MITUBAMBA',
  'Distancia': 0.07615765900419895,
  'Origen': 'POMACHACA'},
 61: {'Destino': 'HUAYTUNA',
  'Distancia': 0.0700856376799044,
  'Origen': 'POMACHACA'},
 62: {'Destino': 'MITUBAMBA',
  'Distancia': 0.07615765900419895,
  'Origen': 'POMACHACA'},
 63: {'Destino': 'POMACHACA',
  'Distancia': 0.004100883929092402,
  'Origen': 'POMACHACA'},
 64: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.07260184746959486,
  'Origen': 'POMACHACA'},
 65: {'Destino': 'CARHUAYOC',
  'Distancia': 0.13583621295147846,
  'Origen': 'POMACHACA'},
 66: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.19637790411601852,
  'Origen': 'POMACHACA'},
 67: {'Destino': 'GAUCHO',
  'Distancia': 0.20144830999539506,
  'Origen': 'POMACHACA'},
 68: {'Destino': 'MARIASH',
  'Distancia': 0.20554940840586292,
  'Origen': 'POMACHACA'},
 69: {'Destino': 'AUYO',
  'Distancia': 0.28673934522487887,
  'Origen': 'POMACHACA'},
 70: {'Destino': 'LUCMA',
  'Distancia': 0.28982240067496157,
  'Origen': 'POMACHACA'},
 71: {'Destino': 'PUCHCA',
  'Distancia': 0.2872173486281713,
  'Origen': 'POMACHACA'},
 72: {'Destino': 'PUCUZ',
  'Distancia': 0.29489541408776865,
  'Origen': 'POMACHACA'},
 73: {'Destino': 'PUCUZ',
  'Distancia': 0.27587469120960834,
  'Origen': 'POMACHACA'},
 74: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.2856719684340713,
  'Origen': 'POMACHACA'},
 75: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.2910386201176711,
  'Origen': 'POMACHACA'},
 76: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.25713168787413143,
  'Origen': 'MITUBAMBA'},
 77: {'Destino': 'LA FLORIDA',
  'Distancia': 0.2643327577978202,
  'Origen': 'MITUBAMBA'},
 78: {'Destino': 'SHAYAPA',
  'Distancia': 0.25708955334669004,
  'Origen': 'MITUBAMBA'},
 79: {'Destino': 'POMACHACA',
  'Distancia': 0.07615765900419895,
  'Origen': 'MITUBAMBA'},
 80: {'Destino': 'HUAYTUNA',
  'Distancia': 0.008477400191098456,
  'Origen': 'MITUBAMBA'},
 81: {'Destino': 'MITUBAMBA', 'Distancia': 0.0, 'Origen': 'MITUBAMBA'},
 82: {'Destino': 'POMACHACA',
  'Distancia': 0.07232098833673047,
  'Origen': 'MITUBAMBA'},
 83: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.008057744163225368,
  'Origen': 'MITUBAMBA'},
 84: {'Destino': 'CARHUAYOC',
  'Distancia': 0.18365058155094963,
  'Origen': 'MITUBAMBA'},
 85: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.2545433386478635,
  'Origen': 'MITUBAMBA'},
 86: {'Destino': 'GAUCHO',
  'Distancia': 0.25948270328675527,
  'Origen': 'MITUBAMBA'},
 87: {'Destino': 'MARIASH',
  'Distancia': 0.2635152563344306,
  'Origen': 'MITUBAMBA'},
 88: {'Destino': 'AUYO',
  'Distancia': 0.21412335609408675,
  'Origen': 'MITUBAMBA'},
 89: {'Destino': 'LUCMA',
  'Distancia': 0.21701934989304256,
  'Origen': 'MITUBAMBA'},
 90: {'Destino': 'PUCHCA',
  'Distancia': 0.2154895392078182,
  'Origen': 'MITUBAMBA'},
 91: {'Destino': 'PUCUZ',
  'Distancia': 0.22201934295236048,
  'Origen': 'MITUBAMBA'},
 92: {'Destino': 'PUCUZ',
  'Distancia': 0.2055094368757748,
  'Origen': 'MITUBAMBA'},
 93: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.2126168620406157,
  'Origen': 'MITUBAMBA'},
 94: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.21790614820375973,
  'Origen': 'MITUBAMBA'},
 95: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.24874887300447845,
  'Origen': 'HUAYTUNA'},
 96: {'Destino': 'LA FLORIDA',
  'Distancia': 0.25594636364089907,
  'Origen': 'HUAYTUNA'},
 97: {'Destino': 'SHAYAPA',
  'Distancia': 0.24871198339042475,
  'Origen': 'HUAYTUNA'},
 98: {'Destino': 'POMACHACA',
  'Distancia': 0.0700856376799044,
  'Origen': 'HUAYTUNA'},
 99: {'Destino': 'MITUBAMBA',
  'Distancia': 0.008477400191098456,
  'Origen': 'HUAYTUNA'},
 100: {'Destino': 'MITUBAMBA',
  'Distancia': 0.008477400191098456,
  'Origen': 'HUAYTUNA'},
 101: {'Destino': 'POMACHACA',
  'Distancia': 0.06614271312851103,
  'Origen': 'HUAYTUNA'},
 102: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.002771383950300089,
  'Origen': 'HUAYTUNA'},
 103: {'Destino': 'CARHUAYOC',
  'Distancia': 0.17517420886078272,
  'Origen': 'HUAYTUNA'},
 104: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.24614458776093234,
  'Origen': 'HUAYTUNA'},
 105: {'Destino': 'GAUCHO',
  'Distancia': 0.25107876493443376,
  'Origen': 'HUAYTUNA'},
 106: {'Destino': 'MARIASH',
  'Distancia': 0.2551080446889103,
  'Origen': 'HUAYTUNA'},
 107: {'Destino': 'AUYO',
  'Distancia': 0.22202785930823435,
  'Origen': 'HUAYTUNA'},
 108: {'Destino': 'LUCMA',
  'Distancia': 0.22489256672909622,
  'Origen': 'HUAYTUNA'},
 109: {'Destino': 'PUCHCA',
  'Distancia': 0.22351358606133942,
  'Origen': 'HUAYTUNA'},
 110: {'Destino': 'PUCUZ',
  'Distancia': 0.22987716319156204,
  'Origen': 'HUAYTUNA'},
 111: {'Destino': 'PUCUZ',
  'Distancia': 0.21368189010068162,
  'Origen': 'HUAYTUNA'},
 112: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.22045166912046807,
  'Origen': 'HUAYTUNA'},
 113: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.2257235765466273,
  'Origen': 'HUAYTUNA'},
 114: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.25713168787413143,
  'Origen': 'MITUBAMBA'},
 115: {'Destino': 'LA FLORIDA',
  'Distancia': 0.2643327577978202,
  'Origen': 'MITUBAMBA'},
 116: {'Destino': 'SHAYAPA',
  'Distancia': 0.25708955334669004,
  'Origen': 'MITUBAMBA'},
 117: {'Destino': 'POMACHACA',
  'Distancia': 0.07615765900419895,
  'Origen': 'MITUBAMBA'},
 118: {'Destino': 'MITUBAMBA', 'Distancia': 0.0, 'Origen': 'MITUBAMBA'},
 119: {'Destino': 'HUAYTUNA',
  'Distancia': 0.008477400191098456,
  'Origen': 'MITUBAMBA'},
 120: {'Destino': 'POMACHACA',
  'Distancia': 0.07232098833673047,
  'Origen': 'MITUBAMBA'},
 121: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.008057744163225368,
  'Origen': 'MITUBAMBA'},
 122: {'Destino': 'CARHUAYOC',
  'Distancia': 0.18365058155094963,
  'Origen': 'MITUBAMBA'},
 123: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.2545433386478635,
  'Origen': 'MITUBAMBA'},
 124: {'Destino': 'GAUCHO',
  'Distancia': 0.25948270328675527,
  'Origen': 'MITUBAMBA'},
 125: {'Destino': 'MARIASH',
  'Distancia': 0.2635152563344306,
  'Origen': 'MITUBAMBA'},
 126: {'Destino': 'AUYO',
  'Distancia': 0.21412335609408675,
  'Origen': 'MITUBAMBA'},
 127: {'Destino': 'LUCMA',
  'Distancia': 0.21701934989304256,
  'Origen': 'MITUBAMBA'},
 128: {'Destino': 'PUCHCA',
  'Distancia': 0.2154895392078182,
  'Origen': 'MITUBAMBA'},
 129: {'Destino': 'PUCUZ',
  'Distancia': 0.22201934295236048,
  'Origen': 'MITUBAMBA'},
 130: {'Destino': 'PUCUZ',
  'Distancia': 0.2055094368757748,
  'Origen': 'MITUBAMBA'},
 131: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.2126168620406157,
  'Origen': 'MITUBAMBA'},
 132: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.21790614820375973,
  'Origen': 'MITUBAMBA'},
 133: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.19989512100348686,
  'Origen': 'POMACHACA'},
 134: {'Destino': 'LA FLORIDA',
  'Distancia': 0.20710039865002533,
  'Origen': 'POMACHACA'},
 135: {'Destino': 'SHAYAPA',
  'Distancia': 0.19965322717651995,
  'Origen': 'POMACHACA'},
 136: {'Destino': 'POMACHACA',
  'Distancia': 0.004100883929092402,
  'Origen': 'POMACHACA'},
 137: {'Destino': 'MITUBAMBA',
  'Distancia': 0.07232098833673047,
  'Origen': 'POMACHACA'},
 138: {'Destino': 'HUAYTUNA',
  'Distancia': 0.06614271312851103,
  'Origen': 'POMACHACA'},
 139: {'Destino': 'MITUBAMBA',
  'Distancia': 0.07232098833673047,
  'Origen': 'POMACHACA'},
 140: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.06864028794374404,
  'Origen': 'POMACHACA'},
 141: {'Destino': 'CARHUAYOC',
  'Distancia': 0.13640598832162745,
  'Origen': 'POMACHACA'},
 142: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.19801278702144295,
  'Origen': 'POMACHACA'},
 143: {'Destino': 'GAUCHO',
  'Distancia': 0.20308135404561387,
  'Origen': 'POMACHACA'},
 144: {'Destino': 'MARIASH',
  'Distancia': 0.20718394934212284,
  'Origen': 'POMACHACA'},
 145: {'Destino': 'AUYO',
  'Distancia': 0.2833985344863264,
  'Origen': 'POMACHACA'},
 146: {'Destino': 'LUCMA',
  'Distancia': 0.28646562538985926,
  'Origen': 'POMACHACA'},
 147: {'Destino': 'PUCHCA',
  'Distancia': 0.2839542097486872,
  'Origen': 'POMACHACA'},
 148: {'Destino': 'PUCUZ',
  'Distancia': 0.29153353751670136,
  'Origen': 'POMACHACA'},
 149: {'Destino': 'PUCUZ',
  'Distancia': 0.2727167825730592,
  'Origen': 'POMACHACA'},
 150: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.2822904627117293,
  'Origen': 'POMACHACA'},
 151: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.2876515128571435,
  'Origen': 'POMACHACA'},
 152: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.2500123277480477,
  'Origen': 'RAHUAPAMPA'},
 153: {'Destino': 'LA FLORIDA',
  'Distancia': 0.25720214192342655,
  'Origen': 'RAHUAPAMPA'},
 154: {'Destino': 'SHAYAPA',
  'Distancia': 0.24998567982386113,
  'Origen': 'RAHUAPAMPA'},
 155: {'Destino': 'POMACHACA',
  'Distancia': 0.07260184746959486,
  'Origen': 'RAHUAPAMPA'},
 156: {'Destino': 'MITUBAMBA',
  'Distancia': 0.008057744163225368,
  'Origen': 'RAHUAPAMPA'},
 157: {'Destino': 'HUAYTUNA',
  'Distancia': 0.002771383950300089,
  'Origen': 'RAHUAPAMPA'},
 158: {'Destino': 'MITUBAMBA',
  'Distancia': 0.008057744163225368,
  'Origen': 'RAHUAPAMPA'},
 159: {'Destino': 'POMACHACA',
  'Distancia': 0.06864028794374404,
  'Origen': 'RAHUAPAMPA'},
 160: {'Destino': 'CARHUAYOC',
  'Distancia': 0.17609784504360274,
  'Origen': 'RAHUAPAMPA'},
 161: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.2473751048125063,
  'Origen': 'RAHUAPAMPA'},
 162: {'Destino': 'GAUCHO',
  'Distancia': 0.2522973794552766,
  'Origen': 'RAHUAPAMPA'},
 163: {'Destino': 'MARIASH',
  'Distancia': 0.2563188714706707,
  'Origen': 'RAHUAPAMPA'},
 164: {'Destino': 'AUYO',
  'Distancia': 0.2202975840902441,
  'Origen': 'RAHUAPAMPA'},
 165: {'Destino': 'LUCMA',
  'Distancia': 0.22314052703397916,
  'Origen': 'RAHUAPAMPA'},
 166: {'Destino': 'PUCHCA',
  'Distancia': 0.22187251482101322,
  'Origen': 'RAHUAPAMPA'},
 167: {'Destino': 'PUCUZ',
  'Distancia': 0.22811427522625824,
  'Origen': 'RAHUAPAMPA'},
 168: {'Destino': 'PUCUZ',
  'Distancia': 0.21217554656934579,
  'Origen': 'RAHUAPAMPA'},
 169: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.21867477569441185,
  'Origen': 'RAHUAPAMPA'},
 170: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.2239349071851062,
  'Origen': 'RAHUAPAMPA'},
 171: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.07886109687924713,
  'Origen': 'CARHUAYOC'},
 172: {'Destino': 'LA FLORIDA',
  'Distancia': 0.08554215031783105,
  'Origen': 'CARHUAYOC'},
 173: {'Destino': 'SHAYAPA',
  'Distancia': 0.0791424793141983,
  'Origen': 'CARHUAYOC'},
 174: {'Destino': 'POMACHACA',
  'Distancia': 0.13583621295147846,
  'Origen': 'CARHUAYOC'},
 175: {'Destino': 'MITUBAMBA',
  'Distancia': 0.18365058155094963,
  'Origen': 'CARHUAYOC'},
 176: {'Destino': 'HUAYTUNA',
  'Distancia': 0.17517420886078272,
  'Origen': 'CARHUAYOC'},
 177: {'Destino': 'MITUBAMBA',
  'Distancia': 0.18365058155094963,
  'Origen': 'CARHUAYOC'},
 178: {'Destino': 'POMACHACA',
  'Distancia': 0.13640598832162745,
  'Origen': 'CARHUAYOC'},
 179: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.17609784504360274,
  'Origen': 'CARHUAYOC'},
 180: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.07539993152515888,
  'Origen': 'CARHUAYOC'},
 181: {'Destino': 'GAUCHO',
  'Distancia': 0.07983240207459136,
  'Origen': 'CARHUAYOC'},
 182: {'Destino': 'MARIASH',
  'Distancia': 0.0835416502410528,
  'Origen': 'CARHUAYOC'},
 183: {'Destino': 'AUYO',
  'Distancia': 0.3913277740577583,
  'Origen': 'CARHUAYOC'},
 184: {'Destino': 'LUCMA',
  'Distancia': 0.39381501680358155,
  'Origen': 'CARHUAYOC'},
 185: {'Destino': 'PUCHCA',
  'Distancia': 0.3940873417962105,
  'Origen': 'CARHUAYOC'},
 186: {'Destino': 'PUCUZ',
  'Distancia': 0.3985643981303448,
  'Origen': 'CARHUAYOC'},
 187: {'Destino': 'PUCUZ',
  'Distancia': 0.3859053244735074,
  'Origen': 'CARHUAYOC'},
 188: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.3890175414656829,
  'Origen': 'CARHUAYOC'},
 189: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.3940234911131637,
  'Origen': 'CARHUAYOC'},
 190: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.0042151262140014455,
  'Origen': 'CARMEN ROSA'},
 191: {'Destino': 'LA FLORIDA',
  'Distancia': 0.010144463761086282,
  'Origen': 'CARMEN ROSA'},
 192: {'Destino': 'SHAYAPA',
  'Distancia': 0.005046805920577871,
  'Origen': 'CARMEN ROSA'},
 193: {'Destino': 'POMACHACA',
  'Distancia': 0.19637790411601852,
  'Origen': 'CARMEN ROSA'},
 194: {'Destino': 'MITUBAMBA',
  'Distancia': 0.2545433386478635,
  'Origen': 'CARMEN ROSA'},
 195: {'Destino': 'HUAYTUNA',
  'Distancia': 0.24614458776093234,
  'Origen': 'CARMEN ROSA'},
 196: {'Destino': 'MITUBAMBA',
  'Distancia': 0.2545433386478635,
  'Origen': 'CARMEN ROSA'},
 197: {'Destino': 'POMACHACA',
  'Distancia': 0.19801278702144295,
  'Origen': 'CARMEN ROSA'},
 198: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.2473751048125063,
  'Origen': 'CARMEN ROSA'},
 199: {'Destino': 'CARHUAYOC',
  'Distancia': 0.07539993152515888,
  'Origen': 'CARMEN ROSA'},
 200: {'Destino': 'GAUCHO',
  'Distancia': 0.0050706513388336085,
  'Origen': 'CARMEN ROSA'},
 201: {'Destino': 'MARIASH',
  'Distancia': 0.009171750160138579,
  'Origen': 'CARMEN ROSA'},
 202: {'Destino': 'AUYO',
  'Distancia': 0.4652433648371499,
  'Origen': 'CARMEN ROSA'},
 203: {'Destino': 'LUCMA',
  'Distancia': 0.46781982332731475,
  'Origen': 'CARMEN ROSA'},
 204: {'Destino': 'PUCHCA',
  'Distancia': 0.4676830852382817,
  'Origen': 'CARMEN ROSA'},
 205: {'Destino': 'PUCUZ',
  'Distancia': 0.4726289509805745,
  'Origen': 'CARMEN ROSA'},
 206: {'Destino': 'PUCUZ',
  'Distancia': 0.4589322012073222,
  'Origen': 'CARMEN ROSA'},
 207: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.4630872860638682,
  'Origen': 'CARMEN ROSA'},
 208: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.4681573658771163,
  'Origen': 'CARMEN ROSA'},
 209: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.005086975722366416,
  'Origen': 'GAUCHO'},
 210: {'Destino': 'LA FLORIDA',
  'Distancia': 0.006195002017749864,
  'Origen': 'GAUCHO'},
 211: {'Destino': 'SHAYAPA',
  'Distancia': 0.006045383445236792,
  'Origen': 'GAUCHO'},
 212: {'Destino': 'POMACHACA',
  'Distancia': 0.20144830999539506,
  'Origen': 'GAUCHO'},
 213: {'Destino': 'MITUBAMBA',
  'Distancia': 0.25948270328675527,
  'Origen': 'GAUCHO'},
 214: {'Destino': 'HUAYTUNA',
  'Distancia': 0.25107876493443376,
  'Origen': 'GAUCHO'},
 215: {'Destino': 'MITUBAMBA',
  'Distancia': 0.25948270328675527,
  'Origen': 'GAUCHO'},
 216: {'Destino': 'POMACHACA',
  'Distancia': 0.20308135404561387,
  'Origen': 'GAUCHO'},
 217: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.2522973794552766,
  'Origen': 'GAUCHO'},
 218: {'Destino': 'CARHUAYOC',
  'Distancia': 0.07983240207459136,
  'Origen': 'GAUCHO'},
 219: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.0050706513388336085,
  'Origen': 'GAUCHO'},
 220: {'Destino': 'MARIASH',
  'Distancia': 0.004102826342899069,
  'Origen': 'GAUCHO'},
 221: {'Destino': 'AUYO', 'Distancia': 0.4700248291526697, 'Origen': 'GAUCHO'},
 222: {'Destino': 'LUCMA',
  'Distancia': 0.47259198351749787,
  'Origen': 'GAUCHO'},
 223: {'Destino': 'PUCHCA',
  'Distancia': 0.47249536400794534,
  'Origen': 'GAUCHO'},
 224: {'Destino': 'PUCUZ', 'Distancia': 0.477394786550923, 'Origen': 'GAUCHO'},
 225: {'Destino': 'PUCUZ',
  'Distancia': 0.4637890492734825,
  'Origen': 'GAUCHO'},
 226: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.46785202615036503,
  'Origen': 'GAUCHO'},
 227: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.4729150521605367,
  'Origen': 'GAUCHO'},
 228: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.008296129820585687,
  'Origen': 'MARIASH'},
 229: {'Destino': 'LA FLORIDA',
  'Distancia': 0.004718528796140812,
  'Origen': 'MARIASH'},
 230: {'Destino': 'SHAYAPA',
  'Distancia': 0.009031882915539536,
  'Origen': 'MARIASH'},
 231: {'Destino': 'POMACHACA',
  'Distancia': 0.20554940840586292,
  'Origen': 'MARIASH'},
 232: {'Destino': 'MITUBAMBA',
  'Distancia': 0.2635152563344306,
  'Origen': 'MARIASH'},
 233: {'Destino': 'HUAYTUNA',
  'Distancia': 0.2551080446889103,
  'Origen': 'MARIASH'},
 234: {'Destino': 'MITUBAMBA',
  'Distancia': 0.2635152563344306,
  'Origen': 'MARIASH'},
 235: {'Destino': 'POMACHACA',
  'Distancia': 0.20718394934212284,
  'Origen': 'MARIASH'},
 236: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.2563188714706707,
  'Origen': 'MARIASH'},
 237: {'Destino': 'CARHUAYOC',
  'Distancia': 0.0835416502410528,
  'Origen': 'MARIASH'},
 238: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.009171750160138579,
  'Origen': 'MARIASH'},
 239: {'Destino': 'GAUCHO',
  'Distancia': 0.004102826342899069,
  'Origen': 'MARIASH'},
 240: {'Destino': 'AUYO',
  'Distancia': 0.4739477284637965,
  'Origen': 'MARIASH'},
 241: {'Destino': 'LUCMA',
  'Distancia': 0.47650829215555024,
  'Origen': 'MARIASH'},
 242: {'Destino': 'PUCHCA',
  'Distancia': 0.4764398968946631,
  'Origen': 'MARIASH'},
 243: {'Destino': 'PUCUZ',
  'Distancia': 0.4813065816649482,
  'Origen': 'MARIASH'},
 244: {'Destino': 'PUCUZ',
  'Distancia': 0.46776460485376337,
  'Origen': 'MARIASH'},
 245: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.47176312398172676,
  'Origen': 'MARIASH'},
 246: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.47682110886159323,
  'Origen': 'MARIASH'},
 247: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.468174040196582,
  'Origen': 'AUYO'},
 248: {'Destino': 'LA FLORIDA',
  'Distancia': 0.47526155599837144,
  'Origen': 'AUYO'},
 249: {'Destino': 'SHAYAPA',
  'Distancia': 0.46823912861378036,
  'Origen': 'AUYO'},
 250: {'Destino': 'POMACHACA',
  'Distancia': 0.28673934522487887,
  'Origen': 'AUYO'},
 251: {'Destino': 'MITUBAMBA',
  'Distancia': 0.21412335609408675,
  'Origen': 'AUYO'},
 252: {'Destino': 'HUAYTUNA',
  'Distancia': 0.22202785930823435,
  'Origen': 'AUYO'},
 253: {'Destino': 'MITUBAMBA',
  'Distancia': 0.21412335609408675,
  'Origen': 'AUYO'},
 254: {'Destino': 'POMACHACA',
  'Distancia': 0.2833985344863264,
  'Origen': 'AUYO'},
 255: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.2202975840902441,
  'Origen': 'AUYO'},
 256: {'Destino': 'CARHUAYOC',
  'Distancia': 0.3913277740577583,
  'Origen': 'AUYO'},
 257: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.4652433648371499,
  'Origen': 'AUYO'},
 258: {'Destino': 'GAUCHO', 'Distancia': 0.4700248291526697, 'Origen': 'AUYO'},
 259: {'Destino': 'MARIASH',
  'Distancia': 0.4739477284637965,
  'Origen': 'AUYO'},
 260: {'Destino': 'LUCMA',
  'Distancia': 0.0036321746929500504,
  'Origen': 'AUYO'},
 261: {'Destino': 'PUCHCA',
  'Distancia': 0.009129573538771375,
  'Origen': 'AUYO'},
 262: {'Destino': 'PUCUZ',
  'Distancia': 0.008543510402649248,
  'Origen': 'AUYO'},
 263: {'Destino': 'PUCUZ',
  'Distancia': 0.023128587721680745,
  'Origen': 'AUYO'},
 264: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.005047188227130013,
  'Origen': 'AUYO'},
 265: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.007101330861199872,
  'Origen': 'AUYO'},
 266: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.47076697457340555,
  'Origen': 'LUCMA'},
 267: {'Destino': 'LA FLORIDA',
  'Distancia': 0.47784651649352844,
  'Origen': 'LUCMA'},
 268: {'Destino': 'SHAYAPA',
  'Distancia': 0.47083766238906494,
  'Origen': 'LUCMA'},
 269: {'Destino': 'POMACHACA',
  'Distancia': 0.28982240067496157,
  'Origen': 'LUCMA'},
 270: {'Destino': 'MITUBAMBA',
  'Distancia': 0.21701934989304256,
  'Origen': 'LUCMA'},
 271: {'Destino': 'HUAYTUNA',
  'Distancia': 0.22489256672909622,
  'Origen': 'LUCMA'},
 272: {'Destino': 'MITUBAMBA',
  'Distancia': 0.21701934989304256,
  'Origen': 'LUCMA'},
 273: {'Destino': 'POMACHACA',
  'Distancia': 0.28646562538985926,
  'Origen': 'LUCMA'},
 274: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.22314052703397916,
  'Origen': 'LUCMA'},
 275: {'Destino': 'CARHUAYOC',
  'Distancia': 0.39381501680358155,
  'Origen': 'LUCMA'},
 276: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.46781982332731475,
  'Origen': 'LUCMA'},
 277: {'Destino': 'GAUCHO',
  'Distancia': 0.47259198351749787,
  'Origen': 'LUCMA'},
 278: {'Destino': 'MARIASH',
  'Distancia': 0.47650829215555024,
  'Origen': 'LUCMA'},
 279: {'Destino': 'AUYO',
  'Distancia': 0.0036321746929500504,
  'Origen': 'LUCMA'},
 280: {'Destino': 'PUCHCA',
  'Distancia': 0.011389439670153639,
  'Origen': 'LUCMA'},
 281: {'Destino': 'PUCUZ',
  'Distancia': 0.005109542934546519,
  'Origen': 'LUCMA'},
 282: {'Destino': 'PUCUZ',
  'Distancia': 0.02639559487869543,
  'Origen': 'LUCMA'},
 283: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.00514634666535428,
  'Origen': 'LUCMA'},
 284: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.003940153931004027,
  'Origen': 'LUCMA'},
 285: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.470556231140334,
  'Origen': 'PUCHCA'},
 286: {'Destino': 'LA FLORIDA',
  'Distancia': 0.47766974081366914,
  'Origen': 'PUCHCA'},
 287: {'Destino': 'SHAYAPA',
  'Distancia': 0.47060187124574526,
  'Origen': 'PUCHCA'},
 288: {'Destino': 'POMACHACA',
  'Distancia': 0.2872173486281713,
  'Origen': 'PUCHCA'},
 289: {'Destino': 'MITUBAMBA',
  'Distancia': 0.2154895392078182,
  'Origen': 'PUCHCA'},
 290: {'Destino': 'HUAYTUNA',
  'Distancia': 0.22351358606133942,
  'Origen': 'PUCHCA'},
 291: {'Destino': 'MITUBAMBA',
  'Distancia': 0.2154895392078182,
  'Origen': 'PUCHCA'},
 292: {'Destino': 'POMACHACA',
  'Distancia': 0.2839542097486872,
  'Origen': 'PUCHCA'},
 293: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.22187251482101322,
  'Origen': 'PUCHCA'},
 294: {'Destino': 'CARHUAYOC',
  'Distancia': 0.3940873417962105,
  'Origen': 'PUCHCA'},
 295: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.4676830852382817,
  'Origen': 'PUCHCA'},
 296: {'Destino': 'GAUCHO',
  'Distancia': 0.47249536400794534,
  'Origen': 'PUCHCA'},
 297: {'Destino': 'MARIASH',
  'Distancia': 0.4764398968946631,
  'Origen': 'PUCHCA'},
 298: {'Destino': 'AUYO',
  'Distancia': 0.009129573538771375,
  'Origen': 'PUCHCA'},
 299: {'Destino': 'LUCMA',
  'Distancia': 0.011389439670153639,
  'Origen': 'PUCHCA'},
 300: {'Destino': 'PUCUZ',
  'Distancia': 0.014070681042508953,
  'Origen': 'PUCHCA'},
 301: {'Destino': 'PUCUZ',
  'Distancia': 0.016149429246880866,
  'Origen': 'PUCHCA'},
 302: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.014121065257267766,
  'Origen': 'PUCHCA'},
 303: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.015324771874325556,
  'Origen': 'PUCHCA'},
 304: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.47558701312798235,
  'Origen': 'PUCUZ'},
 305: {'Destino': 'LA FLORIDA',
  'Distancia': 0.4826611522963063,
  'Origen': 'PUCUZ'},
 306: {'Destino': 'SHAYAPA',
  'Distancia': 0.47566139576908845,
  'Origen': 'PUCUZ'},
 307: {'Destino': 'POMACHACA',
  'Distancia': 0.29489541408776865,
  'Origen': 'PUCUZ'},
 308: {'Destino': 'MITUBAMBA',
  'Distancia': 0.22201934295236048,
  'Origen': 'PUCUZ'},
 309: {'Destino': 'HUAYTUNA',
  'Distancia': 0.22987716319156204,
  'Origen': 'PUCUZ'},
 310: {'Destino': 'MITUBAMBA',
  'Distancia': 0.22201934295236048,
  'Origen': 'PUCUZ'},
 311: {'Destino': 'POMACHACA',
  'Distancia': 0.29153353751670136,
  'Origen': 'PUCUZ'},
 312: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.22811427522625824,
  'Origen': 'PUCUZ'},
 313: {'Destino': 'CARHUAYOC',
  'Distancia': 0.3985643981303448,
  'Origen': 'PUCUZ'},
 314: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.4726289509805745,
  'Origen': 'PUCUZ'},
 315: {'Destino': 'GAUCHO', 'Distancia': 0.477394786550923, 'Origen': 'PUCUZ'},
 316: {'Destino': 'MARIASH',
  'Distancia': 0.4813065816649482,
  'Origen': 'PUCUZ'},
 317: {'Destino': 'AUYO',
  'Distancia': 0.008543510402649248,
  'Origen': 'PUCUZ'},
 318: {'Destino': 'LUCMA',
  'Distancia': 0.005109542934546519,
  'Origen': 'PUCUZ'},
 319: {'Destino': 'PUCHCA',
  'Distancia': 0.014070681042508953,
  'Origen': 'PUCUZ'},
 320: {'Destino': 'PUCUZ',
  'Distancia': 0.030000000000001137,
  'Origen': 'PUCUZ'},
 321: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.009546856707837854,
  'Origen': 'PUCUZ'},
 322: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.0049918944299731415,
  'Origen': 'PUCUZ'},
 323: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.461714248270503,
  'Origen': 'PUCUZ'},
 324: {'Destino': 'LA FLORIDA',
  'Distancia': 0.4688630801588008,
  'Origen': 'PUCUZ'},
 325: {'Destino': 'SHAYAPA',
  'Distancia': 0.46172985979357806,
  'Origen': 'PUCUZ'},
 326: {'Destino': 'POMACHACA',
  'Distancia': 0.27587469120960834,
  'Origen': 'PUCUZ'},
 327: {'Destino': 'MITUBAMBA',
  'Distancia': 0.2055094368757748,
  'Origen': 'PUCUZ'},
 328: {'Destino': 'HUAYTUNA',
  'Distancia': 0.21368189010068162,
  'Origen': 'PUCUZ'},
 329: {'Destino': 'MITUBAMBA',
  'Distancia': 0.2055094368757748,
  'Origen': 'PUCUZ'},
 330: {'Destino': 'POMACHACA',
  'Distancia': 0.2727167825730592,
  'Origen': 'PUCUZ'},
 331: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.21217554656934579,
  'Origen': 'PUCUZ'},
 332: {'Destino': 'CARHUAYOC',
  'Distancia': 0.3859053244735074,
  'Origen': 'PUCUZ'},
 333: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.4589322012073222,
  'Origen': 'PUCUZ'},
 334: {'Destino': 'GAUCHO',
  'Distancia': 0.4637890492734825,
  'Origen': 'PUCUZ'},
 335: {'Destino': 'MARIASH',
  'Distancia': 0.46776460485376337,
  'Origen': 'PUCUZ'},
 336: {'Destino': 'AUYO',
  'Distancia': 0.023128587721680745,
  'Origen': 'PUCUZ'},
 337: {'Destino': 'LUCMA',
  'Distancia': 0.02639559487869543,
  'Origen': 'PUCUZ'},
 338: {'Destino': 'PUCHCA',
  'Distancia': 0.016149429246880866,
  'Origen': 'PUCUZ'},
 339: {'Destino': 'PUCUZ',
  'Distancia': 0.030000000000001137,
  'Origen': 'PUCUZ'},
 340: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.027051108535512593,
  'Origen': 'PUCUZ'},
 341: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.03019369155966672,
  'Origen': 'PUCUZ'},
 342: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.4660475569220338,
  'Origen': 'QUETZAMARCA'},
 343: {'Destino': 'LA FLORIDA',
  'Distancia': 0.4731205352053521,
  'Origen': 'QUETZAMARCA'},
 344: {'Destino': 'SHAYAPA',
  'Distancia': 0.46612278816637787,
  'Origen': 'QUETZAMARCA'},
 345: {'Destino': 'POMACHACA',
  'Distancia': 0.2856719684340713,
  'Origen': 'QUETZAMARCA'},
 346: {'Destino': 'MITUBAMBA',
  'Distancia': 0.2126168620406157,
  'Origen': 'QUETZAMARCA'},
 347: {'Destino': 'HUAYTUNA',
  'Distancia': 0.22045166912046807,
  'Origen': 'QUETZAMARCA'},
 348: {'Destino': 'MITUBAMBA',
  'Distancia': 0.2126168620406157,
  'Origen': 'QUETZAMARCA'},
 349: {'Destino': 'POMACHACA',
  'Distancia': 0.2822904627117293,
  'Origen': 'QUETZAMARCA'},
 350: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.21867477569441185,
  'Origen': 'QUETZAMARCA'},
 351: {'Destino': 'CARHUAYOC',
  'Distancia': 0.3890175414656829,
  'Origen': 'QUETZAMARCA'},
 352: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.4630872860638682,
  'Origen': 'QUETZAMARCA'},
 353: {'Destino': 'GAUCHO',
  'Distancia': 0.46785202615036503,
  'Origen': 'QUETZAMARCA'},
 354: {'Destino': 'MARIASH',
  'Distancia': 0.47176312398172676,
  'Origen': 'QUETZAMARCA'},
 355: {'Destino': 'AUYO',
  'Distancia': 0.005047188227130013,
  'Origen': 'QUETZAMARCA'},
 356: {'Destino': 'LUCMA',
  'Distancia': 0.00514634666535428,
  'Origen': 'QUETZAMARCA'},
 357: {'Destino': 'PUCHCA',
  'Distancia': 0.014121065257267766,
  'Origen': 'QUETZAMARCA'},
 358: {'Destino': 'PUCUZ',
  'Distancia': 0.009546856707837854,
  'Origen': 'QUETZAMARCA'},
 359: {'Destino': 'PUCUZ',
  'Distancia': 0.027051108535512593,
  'Origen': 'QUETZAMARCA'},
 360: {'Destino': 'SHOGOSHMARCA',
  'Distancia': 0.005408514491061695,
  'Origen': 'QUETZAMARCA'},
 361: {'Destino': 'CHAVIN DE HUANTAR',
  'Distancia': 0.4711296062804773,
  'Origen': 'SHOGOSHMARCA'},
 362: {'Destino': 'LA FLORIDA',
  'Distancia': 0.4781965044309714,
  'Origen': 'SHOGOSHMARCA'},
 363: {'Destino': 'SHAYAPA',
  'Distancia': 0.47120890887694306,
  'Origen': 'SHOGOSHMARCA'},
 364: {'Destino': 'POMACHACA',
  'Distancia': 0.2910386201176711,
  'Origen': 'SHOGOSHMARCA'},
 365: {'Destino': 'MITUBAMBA',
  'Distancia': 0.21790614820375973,
  'Origen': 'SHOGOSHMARCA'},
 366: {'Destino': 'HUAYTUNA',
  'Distancia': 0.2257235765466273,
  'Origen': 'SHOGOSHMARCA'},
 367: {'Destino': 'MITUBAMBA',
  'Distancia': 0.21790614820375973,
  'Origen': 'SHOGOSHMARCA'},
 368: {'Destino': 'POMACHACA',
  'Distancia': 0.2876515128571435,
  'Origen': 'SHOGOSHMARCA'},
 369: {'Destino': 'RAHUAPAMPA',
  'Distancia': 0.2239349071851062,
  'Origen': 'SHOGOSHMARCA'},
 370: {'Destino': 'CARHUAYOC',
  'Distancia': 0.3940234911131637,
  'Origen': 'SHOGOSHMARCA'},
 371: {'Destino': 'CARMEN ROSA',
  'Distancia': 0.4681573658771163,
  'Origen': 'SHOGOSHMARCA'},
 372: {'Destino': 'GAUCHO',
  'Distancia': 0.4729150521605367,
  'Origen': 'SHOGOSHMARCA'},
 373: {'Destino': 'MARIASH',
  'Distancia': 0.47682110886159323,
  'Origen': 'SHOGOSHMARCA'},
 374: {'Destino': 'AUYO',
  'Distancia': 0.007101330861199872,
  'Origen': 'SHOGOSHMARCA'},
 375: {'Destino': 'LUCMA',
  'Distancia': 0.003940153931004027,
  'Origen': 'SHOGOSHMARCA'},
 376: {'Destino': 'PUCHCA',
  'Distancia': 0.015324771874325556,
  'Origen': 'SHOGOSHMARCA'},
 377: {'Destino': 'PUCUZ',
  'Distancia': 0.0049918944299731415,
  'Origen': 'SHOGOSHMARCA'},
 378: {'Destino': 'PUCUZ',
  'Distancia': 0.03019369155966672,
  'Origen': 'SHOGOSHMARCA'},
 379: {'Destino': 'QUETZAMARCA',
  'Distancia': 0.005408514491061695,
  'Origen': 'SHOGOSHMARCA'}}

# %%
dictionary = {}
for i in PROVINCIA:
  a = PROVINCIA[i]['Origen']
  dictionary[a] =[]

for i in PROVINCIA:
  a = PROVINCIA[i]['Origen']
  b = PROVINCIA[i]['Destino']
  c = PROVINCIA[i]['Distancia'] 
  midict = {b:c}
  dictionary[a].append(midict)

dictionary
# Out:
# {'AUYO': [{'CHAVIN DE HUANTAR': 0.468174040196582},
#   {'LA FLORIDA': 0.47526155599837144},
#   {'SHAYAPA': 0.46823912861378036},
#   {'POMACHACA': 0.28673934522487887},
#   {'MITUBAMBA': 0.21412335609408675},
#   {'HUAYTUNA': 0.22202785930823435},
#   {'MITUBAMBA': 0.21412335609408675},
#   {'POMACHACA': 0.2833985344863264},
#   {'RAHUAPAMPA': 0.2202975840902441},
#   {'CARHUAYOC': 0.3913277740577583},
#   {'CARMEN ROSA': 0.4652433648371499},
#   {'GAUCHO': 0.4700248291526697},
#   {'MARIASH': 0.4739477284637965},
#   {'LUCMA': 0.0036321746929500504},
#   {'PUCHCA': 0.009129573538771375},
#   {'PUCUZ': 0.008543510402649248},
#   {'PUCUZ': 0.023128587721680745},
#   {'QUETZAMARCA': 0.005047188227130013},
#   {'SHOGOSHMARCA': 0.007101330861199872}],
#  'CARHUAYOC': [{'CHAVIN DE HUANTAR': 0.07886109687924713},
#   {'LA FLORIDA': 0.08554215031783105},
#   {'SHAYAPA': 0.0791424793141983},
#   {'POMACHACA': 0.13583621295147846},
#   {'MITUBAMBA': 0.18365058155094963},
# ...

# %%
#Listas de adyacencia para cada nodo
adj = [[] for _ in range(len(dictionary))]

i = -1
vis = []
orden = []

for origen in dictionary.keys():
  a = origen
  orden.append(a)
  i = i + 1
  for destino_dict in dictionary[origen]:
    
    for z,key in enumerate(destino_dict):
     
      b = key
      c = destino_dict[key]
      adj[i].append((b,c))

adj
# Out:
# [[('LA FLORIDA', 0.007236614678151118),
#   ('SHAYAPA', 0.00103697685605998),
#   ('POMACHACA', 0.198188609950218),
#   ('MITUBAMBA', 0.25713168787413143),
#   ('HUAYTUNA', 0.24874887300447845),
#   ('MITUBAMBA', 0.25713168787413143),
#   ('POMACHACA', 0.19989512100348686),
#   ('RAHUAPAMPA', 0.2500123277480477),
#   ('CARHUAYOC', 0.07886109687924713),
#   ('CARMEN ROSA', 0.0042151262140014455),
#   ('GAUCHO', 0.005086975722366416),
#   ('MARIASH', 0.008296129820585687),
#   ('AUYO', 0.468174040196582),
#   ('LUCMA', 0.47076697457340555),
#   ('PUCHCA', 0.470556231140334),
#   ('PUCUZ', 0.47558701312798235),
#   ('PUCUZ', 0.461714248270503),
#   ('QUETZAMARCA', 0.4660475569220338),
#   ('SHOGOSHMARCA', 0.4711296062804773)],
#  [('CHAVIN DE HUANTAR', 0.007236614678151118),
#   ('SHAYAPA', 0.007455583209918101),
#   ('POMACHACA', 0.20538029869001664),
#   ('MITUBAMBA', 0.2643327577978202),
#   ('HUAYTUNA', 0.25594636364089907),
#   ('MITUBAMBA', 0.2643327577978202),
# ...

# %%
def valid(nodo:str):
  if nodo in vis:
    return False
  else:
    return True

# %%
import heapq as pq #priority queue

arr = []
def DFS(nodito: str, peso: float):
  vis.append(nodito)

  index = list(orden).index(nodito)
  #Busco su index para recorrer sus vecinos

  q = [] # q es la cola soporte de heapq
  for e, w in adj[index]:
    pq.heappush(q, (w, e))
  
  while len(q) > 0 :
    n,v = pq.heappop(q)
    if valid(v):
      arr.append((nodito,v,n))
      DFS(v, n)
      break

# %%
import time
start_time = time.time()
DFS('LA FLORIDA',0)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0005023479461669922 seconds ---

# %%
costo = 0
for a,b in enumerate(arr):
  costo += arr[a][2]

print('Orden del recorrido')
print(vis)
print('Costo del recorrido')
print(costo)
# Out:
# Orden del recorrido
# ['LA FLORIDA', 'MARIASH', 'GAUCHO', 'CARMEN ROSA', 'CHAVIN DE HUANTAR', 'SHAYAPA', 'CARHUAYOC', 'POMACHACA', 'HUAYTUNA', 'RAHUAPAMPA', 'MITUBAMBA', 'PUCUZ', 'SHOGOSHMARCA', 'LUCMA', 'AUYO', 'QUETZAMARCA', 'PUCHCA']
# Costo del recorrido
# 0.548336556469748

# %%
import networkx as nx
G = nx.Graph()
for i,index in enumerate(arr):
  a= arr[i][0]
  c = arr[i][1]
  d= round(arr[i][2],4)
  G.add_edge(a, c, weight=d)

# %%
nx.draw(G, with_labels=True, font_size=4, font_weight="bold",width=0.95,edgecolors='gray')
# Get weights of each edge and assign to labels
labels = nx.get_edge_attributes(G, "weight")
layout = nx.spring_layout(G)
# Draw edge labels using layout and list of labels
nx.draw_networkx_edge_labels(G, pos=layout, edge_labels=labels)
# Out:
# {('AUYO',
#   'QUETZAMARCA'): Text(0.01951468346213822, 0.02203594867015482, '0.005'),
#  ('CARHUAYOC',
#   'POMACHACA'): Text(0.46525491788784423, 0.01786462530369093, '0.1358'),
#  ('CARMEN ROSA',
#   'CHAVIN DE HUANTAR'): Text(0.65049534963795, 0.3413408036958796, '0.0042'),
#  ('CHAVIN DE HUANTAR',
#   'SHAYAPA'): Text(0.8660453720307523, -0.15694035964255293, '0.001'),
#  ('GAUCHO',
#   'CARMEN ROSA'): Text(-0.028112890561031473, 0.8482091673236316, '0.0051'),
#  ('HUAYTUNA',
#   'RAHUAPAMPA'): Text(0.1206876764511638, -0.34081022317867093, '0.0028'),
#  ('LA FLORIDA',
#   'MARIASH'): Text(0.05661584877784914, 0.8646750325928033, '0.0047'),
#  ('LUCMA', 'AUYO'): Text(-0.3100487735061713, 0.31321058924252193, '0.0036'),
#  ('MARIASH',
#   'GAUCHO'): Text(2.659285390504973e-07, 0.7656678888543207, '0.0041'),
#  ('MITUBAMBA',
#   'PUCUZ'): Text(-0.49162952211207944, -0.7205852401848725, '0.2055'),
#  ('POMACHACA',
# ...

# %% [markdown]
# #Complejidad algorítmica

# %% [markdown]
# La complejidad algorítmica de DFS es O (n + m): cada arista
# está procesada por máximo una vez “de ida” y otra “de vuelta”. Cada vértice solamente se procesa una vez, porque los vértices “ya marcados” no serán revisitados.
