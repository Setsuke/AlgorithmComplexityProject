# %% [markdown]
# # **Trabajo Parcial - Complejidad Algorítmica**

# %% [markdown]
# ###Docente: Luis Canval Sánchez

# %% [markdown]
# ###Integrantes:
#
# * William Angulo Valle
# * Sergio Alva Rosales
# * Carlos Izarra Ticlla

# %% [markdown]
# #Introducción

# %% [markdown]
# Dentro de los algoritmos y su complejidad se pueden rescatar conocimientos fundamentales para la resolución de problemas de alta dificultad. Desde utilizar conceptos como Fuerza Bruta hasta técnicas como Divide y Vencerás o Backtracking. En el presente proyecto detallaremos sobre los conocimientos previos de estudio para poder implementar una estimación a la solución para el problema de “El vendedor Viajero” y cumplir el objetivo de hallar el camino óptimo para recorrer los centros poblados del Perú. Los algoritmos a implementarse en este problema se basan en los caminos a tomar por parte del algoritmo sobre el grafo que se basa en información real. Los beneficios que se pueden rescatar sobre el uso de algoritmos son la eficiencia que se obtiene al utilizarlos, debido a que se puede hallar el camino más corto a la solución del problema y cumplir el objetivo en un menor tiempo. En los siguientes puntos explicaremos a mayor detalle sobre nuestro proyecto.

# %% [markdown]
# #Estado del arte

# %% [markdown]
# ##Lectura del Dataset con Pandas
#
# La lectura de los datos proporcionados fue por medio de la biblioteca de software Pandas de Python, la cual es frecuentemente utilizada en el analisis y manipulación de datos. La misma nos fue de gran utilidad para poder establecer un dataframe con los datos requeridos para llevar a cabo los algoritmos correspondientes para la solución del presente problema. En este caso se ha manipulado la información para obtener una columna de Centros Poblados Origen, Centros Poblados Destino, y la Distancia entre las mismas.

# %% [markdown]
# ![dataframeex.png](data:image/png;base64,...)

# %% [markdown]
# #Algoritmo de Minimax
# ¿Qué es?
# Minimax es un algoritmo recursivo y dicha recursión se da por alguna de las situaciones siguientes:
# o Gana algún jugador.
# o Se han explorado N capas, siendo N el límite establecido.
# o Se ha llegado a una situación estática donde no hay grandes cambios de un nivel a otro.
# El espacio de estados se representa mediante árboles alternados, donde:
# o Nodo. Representa una situación del juego.
# o Sucesores de un nodo. Situaciones del juego a las que accede por movimientos legales aplicando sus reglas.
# o Nivel. Contiene todas las situaciones posibles para uno de los jugadores.
# En árbol Minimax es lo mismo que un árbol de juego. De hecho, no es ni siquiera un árbol es en realidad un algoritmo que es usado en un árbol de juego.
# El algoritmo Minimax es una manera muy clara de transformar un árbol de juego en datos que una computadora puede analizar para que haga una decisión inteligente acerca de cual es la movida que es mejor en el momento.
# El algoritmo Minimax es diseñado para dos jugadores: Min y Max. El algoritmo trabaja como sigue: Max empieza y por lo mismo tiene la posición dominante y será el agresor en el juego. Cada vez que haga una movida, el escogerá la mejor movida para si mismo. Min está a la defensiva, y cada vez que haga una movida tratara de poner a Max en la peor posición posible.
# El procedimiento Minimax es un procedimiento de búsqueda hacia adelante.
# Suponga que tenemos un analizador de situaciones que convierte todos los juicios acerca de las situaciones de tablero en un numero simple de calidad global. Suponga también que los números positivos, por convención, indican la ventaja de un jugador y los negativos la ventaja del otro. El grado de ventaja aumenta con el valor absoluto del número.
# El proceso de cálculo de un número que refleje la calidad de tablero se conoce como evaluación estática. El procedimiento que hace el cálculo es un evaluador estático y el número que calcula se conoce como resultado de la evaluación estática.
# El jugador que espera obtener números positivos se conoce como jugador de maximización o maximizador. El otro jugador recibe el nombre de jugador de minimización o minimizador.
#
# ![image.png](data:image/png;base64,...)
#
#
# #Dijkstra
#
# El algoritmo de Dijkstra, también llamado algoritmo de caminos mínimos es un algoritmo para la determinación del camino más corto, dado un vértice origen, hacia el resto de los vértices en un grafo que tiene pesos en cada arista. Su nombre alude a Edsger Dijkstra, científico de la computación de los Países Bajos que lo concibió en 1956 y lo publicó por primera vez en 1959.1
# La idea subyacente en este algoritmo consiste en ir explorando todos los caminos más cortos que parten del vértice origen y que llevan a todos los demás vértices; cuando se obtiene el camino más corto desde el vértice origen hasta el resto de los vértices que componen el grafo, el algoritmo se detiene. Se trata de una especialización de la búsqueda de costo uniforme y, como tal, no funciona en grafos con aristas de coste negativo (al elegir siempre el nodo con distancia menor, pueden quedar excluidos de la búsqueda nodos que en próximas iteraciones bajarían el costo general del camino al pasar por una arista con costo negativo.
#
# Una de sus aplicaciones más importantes reside en el campo de la telemática. Gracias a él, es posible resolver grafos con muchos nodos, lo que sería muy complicado resolver sin dicho algoritmo, encontrando así las rutas más cortas entre un origen y todos los destinos en una red.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Busqueda en Grafos
# En términos generales, un grafo es un conjunto de vértices o también llamados nodos y aristas que se conforman a partir de un par de vértices, estos pueden ser orientados o no. Los algoritmos más esenciales para el desarrollo de este proyecto en lo que respecta a búsqueda en grafos serían los siguientes: Algoritmo de búsqueda en anchura (BFS) y Algoritmo de búsqueda en profundidad (DFS).
#
# El algoritmo de búsqueda en anchura (BFS) permite recorrer elementos de un grafo comenzando por la raíz y explorando todos los hijos de este vértice. Seguidamente se explora cada uno de los hijos hasta encontrar una solución.
# El algoritmo de búsqueda en profundidad (DFS) permite recorrer todos los vértices de un grafo y cuando ya no queden más vértices que recorrer en un camino se regresa haciendo lo que se conoce como Backtracking, y así poder repetir el mismo proceso con cada hermano del vértice ya visitado.

# %% [markdown]
# ![dfsbfs.png](data:image/png;base64,...)

# %% [markdown]
# ##Teoría de Grafos

# %% [markdown]
# Es una estructura muy utilizada para resolver problemas de todo tipo. Esta estructura de datos conciste en v cantidad de nodos (o vertices), que se conenctan por e cantidad de aristas o edges. G = (V, E). Existen dos tipos de grafos, los direccionados y los no direccionados. Los direccionados, cada arista tiene una dirección única a la que puede ir, sin embargo los grafos no direccionados no cuentan con una dirección específica.

# %% [markdown]
# Representación de los grafos:

# %% [markdown]
# Existen diferentes formas de representar un  grafo, y hay muchos métodos para almacenarlos en una computadora. La estructura de datos usada dependerá de las características del grafo, y el algoritmo usado para manipularlo. Entre las más comunes esta las listas y matrices, con frecuencia se usa una combinación de ambas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Como se aprecia en el cuadro, el grafo mostrado es un grafo no dirigido, se puede ver su diversa maneras de representación.

# %% [markdown]
# ##Distancia Euclidiana
# En matemáticas se trata de una función no negatva usada en diversos contextos para calcular la distancia entre dos puntos.También para hallar la longitud de un segmento definido por dos puntos de una recta, del plano o de espacios de mayor dimension.

# %% [markdown]
# ![dist.png](data:image/png;base64,...)

# %% [markdown]
# ##Algoritmo de Fuerza Bruta
# Un algoritmo de Fuerza Bruta representa al algoritmo solución más simple possible y consiste en intentar todas las opciones posibles. De esta manera, se sitúa el patron a seguir en la primera posición y se compara cada uno hasta finalizarse el proceso. Este mismo no require de una fase previa al proceso ni espacios adicionales de manera constante. Fuerza Bruta es utilizado comúnmente para resolver problemas difíciles que no tienen un método directo de resolución.

# %% [markdown]
# ##Backtracking
# Es una técnica que se utiliza en la programación para llevar a cabo una búsqueda sistemática por medio de todas las configuraciones posibles en un espacio de búsqueda. Los algoritmos de este tipo se dedican a la construcción de soluciones posibles de manera que se verifica si esta candidata a ser la solución es una solución al problema y con esta información se continúa con el proceso de resolución del problema. De este modo, se construyen todas las posibles extensiones de la solución candidata, y se invoca recursivamente al algoritmo en las mismas.
#
# Una breve explicación de lo que trata de una forma más concreta es que consiste en enumerar de manera sistemática alternativas de solución al problema y al probar cada una de las alternativas se guarda en memoria del resto de alternativas, esto servirá en el caso de que no se elija el camino correcto para llegar a la solución y se pueda volver a un punto para probar con otras alternativas.
#
# Esta técnica es usualmente representada a modo de árbol debido a que facilita el entendimiento del mismo.

# %% [markdown]
# ![backtraking.png](data:image/png;base64,...)

# %% [markdown]
# # Metodología

# %% [markdown]
# ##Solución DFS

# %%
import heapq as pq #priority queue

arr = []
def DFS(nodito: str, peso: float):
  vis.append(nodito)

  index = list(orden).index(nodito)
  #Busco su index para recorrer sus vecinos

  q = [] # q es la cola soporte de heapq
  for e, w in adj[index]:
    pq.heappush(q, (w, e))
  
  while len(q) > 0 :
    n,v = pq.heappop(q)
    if valid(v):
      arr.append((nodito,v,n))
      DFS(v, n)
      break

# %% [markdown]
# ##Solución Dijkstra

# %%
def dijkstra(adj: list, start: str):
        
    q = [] # cola de prioridad
    dis[start] = 0

    # En nuestra cola vamos a llevar 
    # pares (w, v) = (weight, vertex) = (peso, vertice/nodo)
    # por qué no (v, w) -> las tuplas se ordenan 
    # lexicograficamente por defecto

    pq.heappush(q, (0, start)) 

    while len(q) > 0:
        _, v = pq.heappop(q)

        if vis2[v]: # Si ya lo he visitado antes, no hago nada
            continue 

        vis2[v] = True
        path 
        index = list(vis2).index(v)
        for e, w in adj[index]: # Recorro vecinos
            # Si he encontrado una nueva ruta para
            # llegar al vecino 'e' a través de 'v' usando
            # la arista con peso 'w', meto esa opción
            # a la cola de prioridad
            
            if dis[v] + w < dis[e] and vis2[e] == False:
                dis[e] = dis[v] + w
                path[e] = v
                pq.heappush(q, (dis[e], e))

    return dis

# %% [markdown]
# ##Solución Fuerza Bruta

# %% [markdown]
# Debido a que permutaremos la cantidad de posibilidades del recorrido, en busqueda del camino más corto, la complejidad de esta solución tendrá un tiempo de ejecución de factor polinómico de orden O((n − 1)!), el factorial del número de centros poblados para esta solución es impracticable.
#
#
# *   10 centro poblados = 9! = 362880 posibilidades
# *   100 centro poblados = 99! = 9.332622 E+155 posibilidades
# *   1000 centros poblados = 999! = 10^2565 posibilidades
# *   Numero de Átomos en el Universo: <(10^100)

# %% [markdown]
# #Conclusiones
#
# * Llegamos a la conclusión que el dijkstra en comparación con el algoritmo DFS es mejor en cuanto eficiencia pero no nos brinda una respuesta óptima, sin embargo el algoritmo DFS soluciona el problema de una manera óptima osea el costo de la mejor ruta pero no es eficiente como el algoritmo Dijkstra
# * El algoritmo de fuerza bruta debido la constante iteración de buscar la menor ruta posible, realiza muchas permutaciones y demanda mucha memoria para procesamiento por lo que no es una solución viable para este problema.
# * El uso de la librería Pandas nos fue de gran utilidad para la lectura y manejo de datos por medio de las funciones que se proporcionan en los DataFrames. De esta manera, se puede obtener una lectura de mayor comodidad para ingresar exclusivamente los datos requeridos para que los algoritmos se vuelvan funcionales.
# * Debido a que el problema se describe como un viajero que puede visitar de un centro poblados a todos los demás centros poblado por helicóptero, la matriz de adyacencia de este grafo es simetrico ya que las aristas entre los nodos no son dirigidos, por lo tanto si ejecutamos el dijkstra para el reflejo de esta matriz en una lista de adyacencia no tendremos solución ya que considerará que la distincia minima en su trayecto es la que llega a otro nodo de forma directa y no pasando por 2,3, etc caminos.

# %% [markdown]
# #Bibliografía
#
#
# * Roldán, A. (2019). Backtracking. Recuperado de: https://www.ciberaula.com/cursos/java/backtracking.php [Consulta: 25 de abril de 2021].
# * Universidad de Murcia (UM). (2015). Parte II: Algorítmica. Tema 5.Backtracking. Recuperado de: http://dis.um.es/~nmarin/transparencias-backtracking-AED-II.pdf [Consulta: 26 de abril de 2021].
# * López, M. (2020). DFS vs BFS. AVANTICA an encora company. Recuperado de: https://www.avantica.com/es/blog/dfs-vs-bfs [Consulta: 28 de abril de 2021].
